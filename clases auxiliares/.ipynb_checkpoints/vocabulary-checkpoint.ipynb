# %%
from nltk.corpus import stopwords

# %%
#prueba =["hola","adios","bye"]

# %%
#prueba2 =["hola","bye","nihao"]

# %%
#filtered = [word for word in prueba2 if word not in prueba]

# %%
#filtered
# Out:
# ['nihao']

# %%
texto = open("C:/Users/Diego/Desktop/TFM/datasets/todojunto_sub/set_train_and_validationV2/preparacion//train.en",encoding="utf8",errors='ignore')

# %%
content=texto.readlines()

# %%
dictionary = {}

# %%
lista = []

# %%
hyfon = "-"
hyfon2 = "--"
dot = "."
number1 = "1"
number2 = "2"

# %%
array = [hyfon,hyfon2,dot,number1,number2]

# %%
# Out:
# ['-', '--', '.', '1', '2']

# %%
for line in content:
    line_aux = line.split()
    filtered_line = [word for word in line_aux if word not in stopwords.words('english')]
    filtered_line2 = [word for word in filtered_line if word not in array]
    if (hyfon in filtered_line2):
        if(filtered_line2.index(hyfon) == 0):
            filtered_line2.remove(hyfon)
    for word in filtered_line2:
        word_aux = word.lower()
        if (word_aux in lista):
            dictionary[word_aux] = dictionary[word_aux] + 1
        else:
            lista.append(word_aux)
            dictionary[word_aux] = 1

# %%
dictionary
# Out:
# {'"': 32600,
#  'hurricane': 32,
#  'lucy': 468,
#  'ripped': 122,
#  'across': 676,
#  'puerto': 30,
#  'rico': 96,
#  'last': 5332,
#  'october': 96,
#  '1': 1451,
#  '2': 795,
#  'causing': 80,
#  'even': 6468,
#  'greater': 204,
#  'devastation': 12,
#  'george': 924,
#  'twoyears': 12,
#  'ago': 2424,
#  '.': 431756,
#  'this': 14338,
#  'time': 14708,
#  'damage': 298,
#  'considerable': 18,
#  'estimated': 18,
#  '8': 522,
#  'billion': 136,
#  '--': 6356,
#  'est': 92,
#  "shouldn'": 1086,
#  'tyou': 140,
#  'get': 34050,
#  '?': 240478,
#  'hello': 4554,
#  'henry': 552,
#  'victor': 310,
#  'benezet': 4,
#  'how': 11716,
#  'areyou': 204,
#  'as': 1894,
#  'well': 18918,
#  'expected': 228,
#  'circumstances': 186,
#  "there'": 8926,
#  'charityball': 2,
#  'tonight': 2458,
#  "it'": 43192,
#  'sjust': 58,
#  'questions': 910,
#  'lunderstandwhy': 2,
#  'distressedyesterday': 2,
#  'need': 9830,
#  'make': 10202,
#  'proper': 242,
#  'report': 774,
#  "i'": 75748,
#  'giving': 662,
#  'toast': 214,
#  'and': 26038,
#  'looking': 3180,
#  'forward': 550,
#  ',': 420390,
#  'old': 4898,
#  'boy': 4096,
#  "can'": 13564,
#  'tomorrow': 2254,
#  'seeyou': 46,
#  'station': 674,
#  'arias': 2,
#  'yes': 15586,
#  'hey': 12330,
#  'howyou': 18,
#  'tellmeyourspeech': 2,
#  "won'": 5086,
#  'tbeinsufferablylong': 2,
#  "theywon'": 6,
#  'serve': 338,
#  'dinner': 1076,
#  "you'": 37712,
#  'fi': 140,
#  'nished': 6,
#  "he'": 16444,
#  'nervous': 426,
#  'loves': 572,
#  'center': 330,
#  'ofattention': 4,
#  "don'": 44428,
#  'excuse': 2650,
#  'us': 14568,
#  'go': 31002,
#  'ahead': 1418,
#  'i': 208224,
#  'position': 592,
#  'good': 19282,
#  'handyman': 16,
#  'caseyou': 2,
#  'ever': 5104,
#  'tire': 28,
#  'ofthese': 22,
#  'long': 4934,
#  "policeman'": 8,
#  'hours': 1646,
#  'nothing': 6558,
#  'works': 884,
#  'around': 5176,
#  'just': 7530,
#  'grand': 418,
#  'you': 62202,
#  'getyounger': 2,
#  'every': 4152,
#  'day': 6266,
#  'thankyou': 202,
#  'met': 1514,
#  'detective': 468,
#  'owens': 16,
#  'yesterday': 720,
#  'house': 4080,
#  'happy': 2508,
#  'san': 354,
#  'sebastian': 32,
#  'toyou': 46,
#  'same': 316,
#  'mr.': 6738,
#  'hearst': 32,
#  'think': 19196,
#  'heard': 2778,
#  'actually': 2110,
#  'he': 15716,
#  'reminds': 176,
#  'lot': 3932,
#  'ofyou': 68,
#  'only': 1102,
#  'listens': 42,
#  'suits': 148,
#  "that'": 22774,
#  'unfair': 78,
#  'not': 5508,
#  'listener': 4,
#  'keep': 5594,
#  'anyway': 1832,
#  'cleared': 116,
#  'no': 28330,
#  'formality': 4,
#  'apologize': 350,
#  'timing': 114,
#  "knowyou'": 8,
#  'due': 402,
#  'street': 970,
#  'wejust': 28,
#  'clarify': 14,
#  'ofthe': 404,
#  'details': 252,
#  'your': 5638,
#  'superintendent': 16,
#  'one': 24730,
#  "charity'": 2,
#  'biggest': 300,
#  'supporters': 16,
#  'know': 41188,
#  "would'": 360,
#  "thoughtyou'": 6,
#  'party': 1478,
#  'already': 2536,
#  'fun': 1436,
#  "tuxedo'": 2,
#  'ready': 2804,
#  'must': 5684,
#  'say': 11892,
#  'seem': 924,
#  'high': 1382,
#  'spirits': 164,
#  'doorstep': 30,
#  'behave': 146,
#  "how'": 1634,
#  'chantal': 36,
#  'something': 10938,
#  'mine': 1712,
#  "didn'": 10440,
#  'want': 20756,
#  'sad': 576,
#  'hear': 4304,
#  'we': 19740,
#  'always': 5250,
#  'thoughtyou': 22,
#  'made': 4276,
#  'charming': 248,
#  'couple': 1170,
#  'perhaps': 1034,
#  'dull': 80,
#  'apparently': 344,
#  'see': 19780,
#  'children': 1618,
#  'much': 7194,
#  'both': 436,
#  'ofmy': 18,
#  'daughters': 66,
#  'living': 1276,
#  'mother': 3142,
#  'back': 15640,
#  'new': 5158,
#  'york': 702,
#  'city': 1272,
#  'milk': 270,
#  'sorry': 9124,
#  'thanks': 4464,
#  'charity': 94,
#  'why': 10504,
#  'fund-': 12,
#  'raise': 384,
#  'cappuccino': 24,
#  'machine': 780,
#  'lowlifes': 8,
#  'come': 26340,
#  'enjoy': 642,
#  'solid': 146,
#  'cup': 408,
#  'ofcoffee': 4,
#  'wasjust': 40,
#  'going': 14768,
#  'ask': 3650,
#  'dog': 1610,
#  'the': 27164,
#  'mystery': 350,
#  'like': 29326,
#  'ghost': 422,
#  'got': 23676,
#  'nice': 4866,
#  'ring': 1120,
#  'can': 4488,
#  'start': 2208,
#  'likeyou': 26,
#  'congeniality': 4,
#  'taking': 1796,
#  'hostile': 66,
#  'mannerwith': 2,
#  'case': 1814,
#  'business': 1986,
#  'strange': 892,
#  "bywhat'": 2,
#  'record': 640,
#  'but': 16054,
#  "let'": 9002,
#  'here': 3660,
#  'january': 102,
#  '6': 672,
#  'afternoon': 634,
#  'sayyou': 8,
#  'outjogging': 2,
#  'when': 4594,
#  'family': 2284,
#  'great': 5782,
#  'danes': 4,
#  'butyou': 66,
#  'prefers': 28,
#  'cats': 138,
#  'so': 13496,
#  'doyou': 154,
#  'cat': 508,
#  'too': 610,
#  'unsanitary': 4,
#  'licking': 48,
#  'dumped': 108,
#  'girlfriend': 516,
#  'ofher': 20,
#  'damn': 2398,
#  'thing': 7792,
#  'night': 6008,
#  'slurping': 10,
#  'away': 5770,
#  'a': 9576,
#  'least': 1354,
#  "they'": 9036,
#  'sleeping': 484,
#  'sleep': 1860,
#  'messiest': 2,
#  'canary': 14,
#  'quite': 1518,
#  'rm': 12,
#  'ifi': 14,
#  'what': 37062,
#  'name': 5016,
#  'tango': 96,
#  'write': 1062,
#  'else': 3066,
#  'would': 12340,
#  'waltz': 46,
#  'fox-': 16,
#  'trot': 18,
#  'questioned': 48,
#  'said': 8022,
#  'discovered': 242,
#  'girl': 3950,
#  'logically': 14,
#  'expect': 684,
#  'found': 3050,
#  'suppose': 770,
#  'together': 2690,
#  'body': 1424,
#  'difference': 520,
#  'twoyoung': 2,
#  'girls': 1450,
#  'strangled': 38,
#  'within': 554,
#  'past': 938,
#  'days': 2618,
#  'it': 15092,
#  'myjob': 16,
#  'nd': 48,
#  'murderer': 184,
#  'principal': 44,
#  'witness': 236,
#  'crime': 574,
#  'scene': 418,
#  'now': 8842,
#  'sure': 7222,
#  'facts': 174,
#  'ofyour': 70,
#  'statements': 16,
#  'agree': 550,
#  "doesn'": 4316,
#  'appear': 156,
#  'distressed': 6,
#  'today': 2872,
#  'guest': 264,
#  'please': 9068,
#  'o-': 324,
#  'w': 98,
#  '-': 8145,
#  '!': 137942,
#  'relax': 864,
#  'everyone': 1804,
#  'somewhere': 956,
#  'ifyou': 148,
#  'mind': 3358,
#  'tell': 12984,
#  'came': 3452,
#  'upon': 484,
#  'better': 5308,
#  'run': 2850,
#  'little': 10378,
#  'faster': 396,
#  'getting': 3026,
#  'belly': 112,
#  'round': 712,
#  'fuckin': 1342,
#  "'": 20442,
#  'geezer': 20,
#  'dialect': 10,
#  'saying': 2036,
#  'keeps': 384,
#  'company': 1076,
#  'runs': 252,
#  'took': 2518,
#  'path': 194,
#  'suddenlytango': 2,
#  "wasn'": 2984,
#  'called': 2530,
#  "wouldn'": 2882,
#  'could': 11506,
#  'kept': 772,
#  'calling': 852,
#  "couldn'": 2422,
#  'point': 1726,
#  'obviously': 414,
#  'moving': 1028,
#  'at': 1728,
#  'rst': 34,
#  'thought': 5474,
#  'asleep': 494,
#  'she': 7562,
#  'almost': 1488,
#  'angelic': 8,
#  'way': 10840,
#  'shejust': 16,
#  'lay': 464,
#  'her': 894,
#  'eyes': 1948,
#  'theywere': 26,
#  'dark': 790,
#  'brown': 390,
#  'still': 6130,
#  'open': 2730,
#  'discern': 6,
#  'dead': 4230,
#  'touched': 180,
#  'mean': 8236,
#  'put': 6350,
#  'head': 2838,
#  'chest': 258,
#  'there': 5614,
#  'heartbeat': 44,
#  'that': 8596,
#  'admits': 22,
#  'notyesterday': 2,
#  'hejust': 18,
#  'remember': 4648,
#  'right': 28820,
#  'may': 3730,
#  'neighbor': 98,
#  'miss': 2962,
#  'lazzo': 2,
#  'either': 1264,
#  'another': 3522,
#  'irwin': 62,
#  'also': 1522,
#  'suffers': 24,
#  'memory': 594,
#  'loss': 278,
#  'in': 4438,
#  'whole': 2778,
#  'area': 540,
#  'remembers': 70,
#  'correctly': 50,
#  'who': 5604,
#  'believe': 4846,
#  'personally': 284,
#  'trying': 2732,
#  'truth': 1532,
#  'hounding': 10,
#  'forget': 2026,
#  'tricks': 106,
#  'murder': 590,
#  'thug': 4,
#  'nutcase': 12,
#  'average': 108,
#  'help': 7198,
#  'push': 428,
#  'become': 948,
#  'next': 3522,
#  'police': 1802,
#  'confess': 118,
#  'gotyou': 10,
#  "sayyou'": 2,
#  'aboutyour': 18,
#  'neighbors': 114,
#  'getyou': 8,
#  'whywould': 10,
#  'maybe': 5950,
#  'rich': 546,
#  'because': 2972,
#  'big': 4706,
#  'glamorous': 34,
#  'wife': 2736,
#  'mediocre': 16,
#  'people': 7654,
#  'tolerate': 48,
#  'success': 224,
#  'comes': 1692,
#  'someone': 3314,
#  'exceptional': 40,
#  'movie': 704,
#  'star': 662,
#  'athlete': 24,
#  'oftheir': 4,
#  'strikes': 94,
#  'injustice': 32,
#  "thinkwe'": 4,
#  'far': 1880,
#  'afield': 2,
#  'interesting': 646,
#  'prints': 118,
#  'without': 2786,
#  "neverwould'": 2,
#  'seen': 3112,
#  'otherwords': 2,
#  'story': 1844,
#  'reeks': 10,
#  'leaves': 354,
#  'everywhere': 538,
#  'tax': 150,
#  'attorney': 212,
#  'making': 1510,
#  'fantasies': 40,
#  'payyou': 6,
#  'jesus': 1782,
#  'hold': 3632,
#  'correct': 354,
#  'pick': 1290,
#  "ricardi'": 2,
#  'geez': 46,
#  'gets': 1536,
#  'sometimes': 1294,
#  'gardens': 36,
#  'halfthe': 6,
#  'ricardi': 2,
#  'tevenknow': 2,
#  'missing': 594,
#  'lbring': 2,
#  'youjust': 14,
#  'went': 2772,
#  'offwith': 2,
#  "perhapsyou'": 2,
#  'il': 30938,
#  'understand': 4156,
#  'howour': 2,
#  'earsprick': 2,
#  'timeyourstory': 2,
#  'changes': 284,
#  'andlcertainlyhope': 2,
#  'banking': 28,
#  'lame': 86,
#  'hook': 282,
#  'crap': 460,
#  'ofline': 2,
#  'speaking': 772,
#  'ofdogs': 2,
#  'keepyours': 2,
#  'leash': 28,
#  'lawsuit': 56,
#  'listen': 4150,
#  'ridiculous': 358,
#  'afraid': 1720,
#  'gonna': 14222,
#  'take': 14582,
#  'longer': 856,
#  'notion': 36,
#  'ofcivic': 2,
#  'duty': 430,
#  'citizen': 124,
#  'isjust': 20,
#  'myth': 76,
#  'rememberwho': 4,
#  'remembervery': 4,
#  'ensure': 70,
#  'public': 462,
#  'safety': 292,
#  'except': 748,
#  'inside': 1958,
#  'anyone': 2068,
#  'knew': 3026,
#  'sue': 308,
#  'ellen': 126,
#  'thinking': 1866,
#  'ran': 662,
#  'home': 5758,
#  'or': 1664,
#  'maybeyou': 10,
#  'betterwash': 2,
#  'likeyour': 2,
#  'tone': 154,
#  'frankly': 114,
#  'beginning': 508,
#  'recording': 112,
#  'fucking': 4196,
#  'lawyer': 600,
#  'isjanuary': 2,
#  '7': 650,
#  ':': 15408,
#  '06': 22,
#  'p.': 406,
#  'm.': 318,
#  'sanjuan': 4,
#  'headquarters': 132,
#  'captain': 1390,
#  'with': 1868,
#  "we'": 19944,
#  'talking': 3448,
#  'hide': 714,
#  'age': 554,
#  'profession': 90,
#  'marital': 16,
#  'status': 116,
#  'buchanan': 8,
#  '57': 52,
#  'ilado': 2,
#  'hill': 198,
#  'senior': 126,
#  'partnerwith': 2,
#  'dean': 90,
#  'dumet': 2,
#  'town': 1616,
#  'check': 2172,
#  'chat': 130,
#  'rooms': 270,
#  'websites': 4,
#  'anything': 6454,
#  'any': 872,
#  'hobbies': 28,
#  'computers': 90,
#  'hobby': 80,
#  'photography': 42,
#  'married': 1512,
#  'ten': 1200,
#  'years': 4852,
#  'fertility': 8,
#  'problem': 2586,
#  'ofadopting': 2,
#  'walk': 1608,
#  'somebody': 2020,
#  "else'": 110,
#  'true': 2318,
#  'tact': 10,
#  'afford': 290,
#  'law': 884,
#  'school': 1906,
#  'rememberyou': 2,
#  'waiting': 1674,
#  'tables': 68,
#  'swagger': 10,
#  'drunk': 550,
#  'trotting': 14,
#  'along': 1292,
#  'hot-': 56,
#  'dolls': 34,
#  'spending': 134,
#  'moneyyou': 2,
#  'earn': 86,
#  'matter': 2578,
#  'hand': 2370,
#  'payback': 28,
#  'beforeyou': 4,
#  'ofcourse': 94,
#  'lcalledas': 2,
#  'soonas': 2,
#  'lcamehome': 2,
#  '91': 64,
#  'whatisyour': 2,
#  'emergency': 432,
#  'says': 2622,
#  'hereyou': 6,
#  'bedroom': 274,
#  'lie': 986,
#  'distraught': 8,
#  'argument': 92,
#  'earlier': 294,
#  'adds': 24,
#  'downstairs': 316,
#  'upstairs': 568,
#  'instructive': 4,
#  'real': 3316,
#  'special': 1058,
#  'ahallway': 2,
#  'hallway': 74,
#  'sixty': 66,
#  'feet': 968,
#  'possibly': 284,
#  'extra': 428,
#  'bedrooms': 30,
#  'never': 10296,
#  'used': 2376,
#  'redecorated': 2,
#  'mywife': 10,
#  'our': 1324,
#  'room': 3224,
#  'separate': 170,
#  'unbearable': 46,
#  'promiseyou': 4,
#  'reason': 1388,
#  'regardless': 34,
#  'ofwhatyou': 2,
#  'ofme': 18,
#  'love': 8858,
#  'loved': 884,
#  'everwanted': 2,
#  'happywith': 4,
#  'pitter-': 2,
#  'patter': 4,
#  'oflittle': 2,
#  'certainly': 594,
#  'pays': 120,
#  'advertise': 8,
#  'ben': 536,
#  'thomas': 276,
#  'caughtyou': 2,
#  'act': 884,
#  'men': 3288,
#  'subtle': 40,
#  "where'": 2268,
#  'had': 224,
#  'tidy': 40,
#  'discuss': 292,
#  'pretty': 2478,
#  'exhausted': 102,
#  'canaries': 14,
#  'dogs': 580,
#  'talk': 5574,
#  'la': 762,
#  'perla': 8,
#  'happenednot': 2,
#  'toolong': 2,
#  'justovertwo': 2,
#  'weeks': 942,
#  "girl'": 148,
#  'paulina': 22,
#  'valera': 8,
#  'astreethooker': 2,
#  'amotelnot': 2,
#  'faraway': 16,
#  'thinkitstarted': 2,
#  'thestreets': 2,
#  'luredorsheran': 2,
#  'thekiller': 4,
#  'leftherbodyin': 2,
#  'dump': 200,
#  'yeah': 20422,
#  'introduce': 288,
#  '29': 66,
#  'minutes': 2348,
#  'told': 5134,
#  'realize': 526,
#  'important': 1594,
#  'raising': 88,
#  'event': 186,
#  'two': 8144,
#  'countless': 32,
#  'whose': 442,
#  'homes': 92,
#  'blown': 142,
#  'sir': 7512,
#  'sponsors': 14,
#  'react': 58,
#  "henry'": 12,
#  'accused': 94,
#  'imagine': 694,
#  'extremely': 170,
#  'grateful': 180,
#  'safe': 1296,
#  '9': 536,
#  '00': 1010,
#  'okay': 14780,
#  'timeyou': 6,
#  'give': 8704,
#  'speech': 384,
#  'patrol': 184,
#  'officers': 212,
#  'wrote': 472,
#  'license': 250,
#  'plate': 198,
#  'number': 1890,
#  'range': 238,
#  'rover': 50,
#  'parked': 68,
#  'vicinity': 22,
#  'expensive': 232,
#  'vehicle': 206,
#  'attracted': 70,
#  'attention': 776,
#  "anytimeyou'": 2,
#  'me': 1544,
#  'hoping': 312,
#  'whereyou': 12,
#  'three': 4404,
#  'sergeant': 548,
#  'opie': 16,
#  'serving': 94,
#  'coffee': 874,
#  'stand-': 22,
#  'citizens': 98,
#  'likeyourself': 2,
#  'sister-': 20,
#  'in-': 298,
#  "law'": 18,
#  'knocked': 122,
#  'club': 476,
#  'andlhadthis': 2,
#  'inspiration': 38,
#  'drop': 1132,
#  'christmas': 842,
#  'gifts': 88,
#  'forthekids': 2,
#  'maria': 124,
#  'andpaco': 2,
#  'rodriguez': 24,
#  'should': 468,
#  'book': 1322,
#  "chantal'": 6,
#  'older': 286,
#  'sister': 1146,
#  'greatkids': 2,
#  'fine': 4158,
#  'complicated': 190,
#  'paco': 36,
#  'merry': 180,
#  'gave': 1748,
#  'bit': 2258,
#  'ofdirt': 2,
#  'stopped': 558,
#  'sound': 994,
#  'friendly': 196,
#  'whyyou': 10,
#  'thaw': 8,
#  'ice': 682,
#  'call': 5958,
#  'window': 714,
#  'ofopportunity': 4,
#  'driving': 502,
#  'terribly': 146,
#  'lmostdefinitelyneeded': 2,
#  'offtheliquor': 2,
#  "perla'": 2,
#  'idea': 2552,
#  'man': 14360,
#  'wearing': 572,
#  'armani': 18,
#  'where': 6066,
#  'lfoundabench': 4,
#  'lsatdown': 2,
#  'woke': 232,
#  'felt': 836,
#  "what'": 10894,
#  'stop': 6262,
#  'shoving': 10,
#  'fist': 88,
#  'throat': 406,
#  'rather': 842,
#  'drove': 190,
#  'all': 10010,
#  'sisters': 168,
#  'lmetpaco': 2,
#  'ahotlocalartist': 2,
#  'busted': 172,
#  'smoking': 218,
#  'grass': 148,
#  'island': 602,
#  'smoke': 536,
#  'fancy': 262,
#  'hanging': 276,
#  'handsome': 280,
#  'successful': 100,
#  'younger': 158,
#  'is': 5802,
#  'necessary': 340,
#  'twenty': 268,
#  'goddamn': 1252,
#  'outrage': 24,
#  'pry': 30,
#  'private': 470,
#  'affairs': 106,
#  'soap': 140,
#  'opera': 210,
#  'insinuations': 2,
#  'look': 15102,
#  'atyou': 6,
#  'doing': 76,
#  'bang-': 30,
#  'upjob': 2,
#  'policing': 4,
#  'butt': 238,
#  'lucky': 1058,
#  'ajob': 6,
#  'really': 10338,
#  'cold': 966,
#  'drink': 1728,
#  'stronger': 194,
#  'stashed': 28,
#  'itgonna': 2,
#  'togetme': 2,
#  'outofhere': 6,
#  'march': 244,
#  'army': 762,
#  'ofattorneys': 2,
#  'sjustyou': 2,
#  'kate': 440,
#  'consuelo': 8,
#  'ifhaving': 2,
#  'difficult': 464,
#  'marriage': 450,
#  'makes': 1646,
#  'son': 3562,
#  'ofsam': 2,
#  'touche': 6,
#  'tooyoung': 2,
#  'consuelojust': 2,
#  'hates': 198,
#  'cop': 814,
#  'stuckwith': 2,
#  'guns': 488,
#  "isn'": 3804,
#  'exciting': 208,
#  'harassing': 16,
#  'folks': 472,
#  'running': 1190,
#  'cocktail': 64,
#  'soirees': 6,
#  'gee': 168,
#  'whiz': 26,
#  'wish': 1718,
#  'whatyou': 62,
#  'enough': 3790,
#  'green': 682,
#  'monster': 332,
#  'extends': 12,
#  "sister'": 96,
#  'tried': 1374,
#  'reasons': 262,
#  'despite': 102,
#  "mother'": 342,
#  'objections': 56,
#  'closer': 450,
#  'beautiful': 2178,
#  'women': 1462,
#  'they': 8832,
#  'breed': 58,
#  'unto': 88,
#  'woman': 3382,
#  'moves': 220,
#  'life': 6284,
#  'unchallenged': 2,
#  'everything': 4664,
#  'theywant': 6,
#  'first': 5892,
#  'daddies': 18,
#  'boyfriends': 28,
#  'husbands': 48,
#  'somebodyyounger': 2,
#  'taught': 364,
#  "hopeyou'": 4,
#  'gotten': 358,
#  'petty': 50,
#  'thrill': 58,
#  'pulling': 214,
#  'curtain': 102,
#  'sick': 1234,
#  'responsible': 284,
#  'killer': 464,
#  'phantom': 108,
#  'attorney-': 2,
#  'at-': 30,
#  "ifyou'": 34,
#  'convinced': 174,
#  'guilty': 340,
#  'construing': 2,
#  'dysfunctional': 8,
#  'easier': 246,
#  'foryou': 116,
#  'sell': 566,
#  'river': 432,
#  'choose': 486,
#  'becauseyou': 6,
#  'asked': 1544,
#  'fed': 178,
#  'line': 1564,
#  'ofcrap': 6,
#  'ofquestions': 6,
#  'leaving': 1002,
#  'exhaustion': 14,
#  'ballroom': 34,
#  'full': 1168,
#  'ofpeople': 2,
#  'exactly': 1966,
#  'anywhere': 726,
#  'knuckle-': 2,
#  'dragger': 2,
#  'careful': 1026,
#  'be': 1412,
#  'many': 2906,
#  'possibilities': 58,
#  'serious': 1076,
#  'read': 1876,
#  'rights': 194,
#  'step': 944,
#  'remain': 372,
#  'silent': 278,
#  'on': 1922,
#  'charge': 668,
#  'nap': 94,
#  'bench': 50,
#  'counts': 92,
#  'rape': 132,
#  'persons': 54,
#  'ofsue': 2,
#  'huddy': 12,
#  'raped': 146,
#  'huh': 3588,
#  'cannot': 1118,
#  'court': 504,
#  'appoint': 24,
#  'explained': 62,
#  'outside': 1344,
#  'minute': 2364,
#  'ofthat': 24,
#  'ifhe': 16,
#  'lawyers': 110,
#  'opens': 280,
#  'wallet': 142,
#  'trots': 6,
#  'hardball': 6,
#  'mouthpiece': 8,
#  'lose': 1304,
#  'ass': 2378,
#  'playing': 1098,
#  'soft': 222,
#  'butterballing': 2,
#  'let': 9528,
#  'hammer': 82,
#  'guy': 4902,
#  'sit': 2290,
#  'shut': 2418,
#  'saw': 3196,
#  "victor'": 26,
#  'nostrils': 8,
#  'flare': 44,
#  'chewed': 14,
#  'blowing': 140,
#  'pooch': 10,
#  'notorious': 28,
#  'ambushed': 22,
#  'tidbit': 2,
#  'owned': 112,
#  'devastating': 18,
#  'moment': 1610,
#  ...}

# %%
l = []

# %%
for key,value in dictionary.items():
    tupl = [key,value]
    l.append(tupl)

# %%
l.sort(key=lambda x: x[1])

# %%
l2 = list(reversed(l))

# %%
final_list = l2[3:17003]

# %%
vocab_en = open("C:/Users/Diego/Desktop/TFM/datasets/todojunto_sub/set_train_and_validationV2/preparacion/recortado_git/vocab.en","w",encoding="utf8")

# %%
vocab_vi = open("C:/Users/Diego/Desktop/TFM/datasets/todojunto_sub/set_train_and_validationV2/preparacion/recortado_git/vocab.vi","w",encoding="utf8")

# %%
for element in final_list:
    line = element[0]+'\n'
    vocab_en.write(line)
    vocab_vi.write(line)

# %%
vocab_en.close()
vocab_vi.close()

# %%
# for ap in words:
#     a = ap.lower()
#     if(a in lista):
#         dictionary[a] = dictionary [a] +1
#     else:
#         lista.append(a)
#         dictionary[a] = 1
