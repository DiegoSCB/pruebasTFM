# %%
import re
import fileinput
import glob
import sys

# %% [markdown]
# # Way to eliminate xml tags

# %%
text = re.sub('<[^<]+>', "", open("C:/Users/Diego/Desktop/TFM/datasets/todojunto/todo.xml",encoding="utf8").read())
with open("C:/Users/Diego/Desktop/TFM/datasets/todojunto/todo.xml", "w") as f:
    f.write(text)

# %%
texto = open("C:/Users/Diego/Desktop/TFM/datasets/todojunto/todo.xml",encoding="utf8")

# %%
contenido = texto.readlines(500)

# %%
linea = []

# %%
texto.close()

# %%
text_in_lines = open("C:/Users/Diego/Desktop/TFM/datasets/todojunto/text_in_lines.txt","w",encoding="utf8")

# %%
i = 0

# %%
for line in contenido:
    i = i+1
    print("logitud original de la linea: ",len(line))
    print("contenido de la linea: ",line)
    print("linea numero : ",i)
    line = line.strip()
    print("longitud despues de strip: ",len(line))
    print("contenido de la linea despues de strip: ",line)
    if len(line)>0:
        print("1111111 he entrado dentro del primer if porque mi len es: ",len(line))
        linea.append(line)
    if len(line) == 0:
        print("222222 he entrado dentro del segundo if porque mi len es: ",len(line))
        if linea:
            linea_aux = []
            sentence = " ".join(linea)
            text_in_lines.write(sentence+'\n')
            sentence = ""
            linea =[]
# Out:
# logitud original de la linea:  1
# contenido de la linea:
#
# linea numero :  1
# longitud despues de strip:  0
# contenido de la linea despues de strip:
# 222222 he entrado dentro del segundo if porque mi len es:  0
# logitud original de la linea:  1
# contenido de la linea:
#
# linea numero :  2
# longitud despues de strip:  0
# contenido de la linea despues de strip:
# 222222 he entrado dentro del segundo if porque mi len es:  0
# logitud original de la linea:  3
# contenido de la linea:
#
# linea numero :  3
# longitud despues de strip:  0
# contenido de la linea despues de strip:
# 222222 he entrado dentro del segundo if porque mi len es:  0
# logitud original de la linea:  5
# contenido de la linea:
#
# linea numero :  4
# longitud despues de strip:  0
# contenido de la linea despues de strip:
# 222222 he entrado dentro del segundo if porque mi len es:  0
# logitud original de la linea:  6
# contenido de la linea:      "
#
# linea numero :  5
# longitud despues de strip:  1
# ...

# %%
text_in_lines.close()
